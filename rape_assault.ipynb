# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('Sexual Assault Prevention Questionaire (Responses).xlsx')
data.head()
data.shape
(data.columns)
data.index
# Out:
# RangeIndex(start=0, stop=1004, step=1)

# %%
data.head()
# Out:
#                 Timestamp What is your current age?  \
# 0 2019-04-17 13:38:40.860                     35-45
# 1 2019-04-17 19:17:05.661                     18-25
# 2 2019-04-17 19:54:41.168                     18-25
# 3 2019-04-17 16:39:57.570                     18-25
# 4 2019-04-17 19:06:38.610                     18-25
#
#   Which of the categories best describe you? How do you identify yourself?  \
# 0                                      White                          Male
# 1                     Asian/Pacific Islander                        Female
# 2                     Asian/Pacific Islander                        Female
# 3                                      Black                        Female
# 4                                      Other                          Male
#
#   Do you own or carry any forms of protection in case of sexual assault, attack, or other potential harm?  \
# 0          No, I do not own any forms of protection.
# ...

# %%
renam= {'What is your current age?':'Age', 'Which of the categories best describe you?':'Category',
       'How do you identify yourself?':'Identification'}
dataa = data.rename(columns=renam)
data.head()
# Out:
#                 Timestamp What is your current age?  \
# 0 2019-04-17 13:38:40.860                     35-45
# 1 2019-04-17 19:17:05.661                     18-25
# 2 2019-04-17 19:54:41.168                     18-25
# 3 2019-04-17 16:39:57.570                     18-25
# 4 2019-04-17 19:06:38.610                     18-25
#
#   Which of the categories best describe you? How do you identify yourself?  \
# 0                                      White                          Male
# 1                     Asian/Pacific Islander                        Female
# 2                     Asian/Pacific Islander                        Female
# 3                                      Black                        Female
# 4                                      Other                          Male
#
#   Do you own or carry any forms of protection in case of sexual assault, attack, or other potential harm?  \
# 0          No, I do not own any forms of protection.
# ...

# %%
data.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                   datetime64[ns]
# What is your current age?                                                                                                                                                                                                           object
# Which of the categories best describe you?                                                                                                                                                                                          object
# How do you identify yourself?                                                                                                                                                                                                       object
# ...

# %%
data.get_dtype_counts()
# Out:
# float64            1
# datetime64[ns]     1
# object            10
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                                                                     0
# What is your current age?                                                                                                                                                                                                     0
# Which of the categories best describe you?                                                                                                                                                                                    0
# How do you identify yourself?                                                                                                                                                                                                 0
# ...

# %%
data.iloc[:, 3].value_counts()
# Out:
# Female               537
# Male                 461
# Prefer not to say      3
# agender                1
# Nonbinary              1
# Genderqueer            1
# Name: How do you identify yourself?, dtype: int64

# %% [markdown]
# *There are 537 females, 461 males, 3 people did'nt specify, 1 agender, 1 nonbinary and 1 genderqueer*

# %%
data.iloc[:, 11].groupby(data.iloc[:, 3])+

# %%
data.describe(include=[np.number]).T
# Out:
#                                                      count      mean  \
# How comfortable do you feel going to the author...  1003.0  6.481555
#
#                                                          std  min  25%  50%  \
# How comfortable do you feel going to the author...  2.812931  1.0  5.0  7.0
#
#                                                     75%   max
# How comfortable do you feel going to the author...  9.0  10.0

# %%
data.describe(include=np.object).T
# Out:
#                                                    count unique  \
# What is your current age?                           1004      6
# Which of the categories best describe you?          1004     17
# How do you identify yourself?                       1004      6
# Do you own or carry any forms of protection in ...  1004     20
# Would you buy a product that would help protect...  1004      4
# Have you ever used any commercial DNA testing s...  1004      2
# Have you ever been a victim of sexual assault o...  1004      3
# Have you ever witnessed assault or rape?            1003      2
# If you answered "Yes" or "Maybe" to "Have you e...   444      4
# If you did not file a police report or go to th...   230    211
#
#                                                                                                   top  \
# What is your current age?                                                                       25-35
# ...

# %%
data.groupby(data.iloc[:, 3])[]

# %%
file = open('example.txt', 'w')
l = ['line1', 'line 2', 'line 3']
for item in l:
    file.write(item + '\n')
file.close()

# %%
with open('example.txt', 'w') as file:
    l = ['line1', 'line 2', 'line 3']
    for item in l:
        file.write(item)
